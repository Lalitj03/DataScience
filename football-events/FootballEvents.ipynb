# %% [markdown]
# # Football Events

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv("./events.csv")
df.head(10)
# Out:
#      id_odsp    id_event  sort_order  time  \
# 0  UFot0hit/   UFot0hit1           1     2
# 1  UFot0hit/   UFot0hit2           2     4
# 2  UFot0hit/   UFot0hit3           3     4
# 3  UFot0hit/   UFot0hit4           4     7
# 4  UFot0hit/   UFot0hit5           5     7
# 5  UFot0hit/   UFot0hit6           6     9
# 6  UFot0hit/   UFot0hit7           7    10
# 7  UFot0hit/   UFot0hit8           8    11
# 8  UFot0hit/   UFot0hit9           9    11
# 9  UFot0hit/  UFot0hit10          10    13
#
#                                                 text  event_type  event_type2  \
# 0  Attempt missed. Mladen Petric (Hamburg) left f...           1         12.0
# 1  Corner,  Borussia Dortmund. Conceded by Dennis...           2          NaN
# 2  Corner,  Borussia Dortmund. Conceded by Heiko ...           2          NaN
# 3           Foul by Sven Bender (Borussia Dortmund).           3          NaN
# 4  Gokhan Tore (Hamburg) wins a free kick in the ...           8          NaN
# ...

# %%
num_red_card = (len(df.loc[df['event_type'] == 6]))
print(num_red_card)
# Out:
# 1152

# %%
print("Barcelona Penalty Home: {0}".format(len(df.loc[df['event_team'] == "Barcelona"].loc[df['event_type'] == 11].loc[df['side'] == 1])))
# Out:
# Barcelona Penalty Home: 26

# %%
print("Barcelona Penalty Away: {0}".format(len(df.loc[df['event_team'] == "Barcelona"].loc[df['event_type'] == 11].loc[df['side'] == 2])))
# Out:
# Barcelona Penalty Away: 19

# %%
df.loc[df['event_team'] == "Barcelona"].loc[df['event_type'] == 11].loc[df['side'] == 1]
# Out:
#           id_odsp    id_event  sort_order  time  \
# 111329  APyAMsnj/  APyAMsnj83          83    88
# 116300  CQT2oIU7/  CQT2oIU758          58    58
# 142204  xdeDsU5P/  xdeDsU5P33          33    32
# 142238  xdeDsU5P/  xdeDsU5P67          67    58
# 142820  8Sqrx34Q/  8Sqrx34Q99          99    78
# 226009  ITnWQbL7/  ITnWQbL724          24    28
# 280817  hh0RuslQ/  hh0RuslQ11          11    16
# 307142  hQ9HcUOg/  hQ9HcUOg39          39    41
# 358090  A77CKEhl/  A77CKEhl26          26    19
# 358120  A77CKEhl/  A77CKEhl56          56    40
# 386610  niXnbLtA/  niXnbLtA39          39    47
# 449624  C2bRqvuq/  C2bRqvuq14          14    14
# 592749  IaZyZ2oi/  IaZyZ2oi55          55    64
# 606769  ET10nDL7/  ET10nDL747          47    54
# 639504  lvINqZHa/   lvINqZHa6           6     8
# 687118  xGW7WFv4/  xGW7WFv465          65    60
# 687134  xGW7WFv4/  xGW7WFv481          81    75
# 701672  2wbufVgP/  2wbufVgP20          20    21
# ...
